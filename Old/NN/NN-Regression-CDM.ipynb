# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# make numpy print_outs easier to read
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing

# %%
dataset = pd.read_csv('/home/as2c/Sharif/7th Semester/ML/project_from_scratch/Data Processing/Mined Data/Samples Without Nan - Denc With Nan/All CDM/denc_CDM')

dataset = dataset[dataset.halo_mass > 1500]
dataset.head()
# Out:
#          id  haloID  halo_mass         vx         vy         vz  dc for 4.9  \
# 0   8981131     414     1504.0  252.71005 -464.23950  509.94550   -0.104304
# 4  12884124     437     6128.0  146.78067 -180.20927 -558.39777   -0.096293
# 6   2257875     666     9532.0  575.86200  -85.59395 -412.46198   -0.127303
# 8  11109558     369     3092.0 -246.73933  909.41460 -568.12305   -0.081046
# 9   6679801     222     2715.0  -70.51831 -158.75307  357.48340   -0.118000
#
#    dc for 6.8  dc for 8.7  dc for 10.6  dc for 12.4  dc for 14.3  dc for 16.2  \
# 0   -0.029082   -0.005112     0.008240     0.010480     0.008167     0.010448
# 4   -0.056209   -0.018338    -0.008840    -0.005842    -0.001478    -0.000614
# 6   -0.065640   -0.020899    -0.015006    -0.003321     0.006867     0.015352
# 8   -0.050181   -0.023088    -0.007344     0.002319     0.000317    -0.002009
# 9   -0.079155   -0.056386    -0.042354    -0.032168    -0.023946    -0.020096
#
#    dc for 18.1  dc for 20.0
# 0     0.010271     0.010377
# 4     0.003277     0.007512
# 6     0.022183     0.021778
# 8    -0.002321    -0.003806
# 9    -0.016438    -0.012874

# %%
train_dataset, test_dataset = train_test_split(dataset, test_size=0.01, random_state= 43)

print(dataset.shape, train_dataset.shape, test_dataset.shape)
train_dataset.describe().transpose()
# Out:
# (62745, 15) (62117, 15) (628, 15)
#                count          mean           std           min           25%  \
# id           62117.0  8.718506e+06  3.608334e+06  2.131461e+06  5.969371e+06
# haloID       62117.0  6.444596e+02  3.592689e+02  1.100000e+01  3.740000e+02
# halo_mass    62117.0  4.178574e+03  2.959321e+03  1.504000e+03  2.221000e+03
# vx           62117.0  4.222902e+01  3.738682e+02 -1.234874e+03 -2.289860e+02
# vy           62117.0 -1.257434e+01  3.826963e+02 -1.571377e+03 -2.573601e+02
# vz           62117.0  1.069141e+02  3.836045e+02 -1.311025e+03 -1.385883e+02
# dc for 4.9   62117.0 -1.072756e-01  2.079983e-02 -1.278203e-01 -1.244608e-01
# dc for 6.8   62117.0 -6.036747e-02  2.091095e-02 -9.957240e-02 -7.623770e-02
# dc for 8.7   62117.0 -3.546637e-02  1.860968e-02 -8.335055e-02 -4.851572e-02
# dc for 10.6  62117.0 -2.278377e-02  1.698984e-02 -7.282418e-02 -3.456273e-02
# dc for 12.4  62117.0 -1.535336e-02  1.517255e-02 -6.515852e-02 -2.577157e-02
# dc for 14.3  62117.0 -1.016039e-02  1.355707e-02 -5.933913e-02 -1.931408e-02
# dc for 16.2  62117.0 -6.135538e-03  1.228346e-02 -5.043344e-02 -1.436584e-02
# dc for 18.1  62117.0 -2.857743e-03  1.120106e-02 -4.283442e-02 -1.043583e-02
# dc for 20.0  62117.0 -1.736381e-04  1.021138e-02 -3.522791e-02 -7.150482e-03
#
#                       50%           75%           max
# id           9.001787e+06  1.201096e+07  1.464620e+07
# haloID       6.800000e+02  9.960000e+02  1.250000e+03
# halo_mass    3.182000e+03  5.008000e+03  3.125200e+04
# vx           3.662466e+01  2.992638e+02  1.362094e+03
# vy          -6.135298e-01  2.476055e+02  1.185835e+03
# vz           1.129780e+02  3.679354e+02  1.349212e+03
# dc for 4.9  -1.138654e-01 -9.551734e-02  7.852109e-03
# dc for 6.8  -6.175075e-02 -4.706933e-02  3.761617e-02
# dc for 8.7  -3.650051e-02 -2.299503e-02  4.355439e-02
# dc for 10.6 -2.297852e-02 -1.134270e-02  4.234717e-02
# dc for 12.4 -1.521587e-02 -4.849219e-03  4.375428e-02
# dc for 14.3 -1.013308e-02 -7.973403e-04  3.452373e-02
# dc for 16.2 -6.329468e-03  2.190942e-03  3.308366e-02
# dc for 18.1 -3.359511e-03  4.862937e-03  3.412503e-02
# dc for 20.0 -7.353897e-04  6.937638e-03  3.342270e-02

# %%
# split features from labels
train_features = train_dataset.copy()
test_features = test_dataset.copy()

train_features.pop('haloID')
test_features.pop('haloID')
train_features.pop('id')
test_features.pop('id')

train_labels = train_features.pop('halo_mass')
test_labels = test_features.pop('halo_mass')

# %%
def plot(feature1, feature2, x=None, y=None):
    plt.figure(figsize=(10, 8))
    plt.scatter(train_features[feature1], train_features[feature2], label='Data')
    if x is not None and y is not None:
        plt.plot(x, y, color='k', label='Predictions')
    plt.xlabel(feature1)
    plt.ylabel(feature2)
    plt.legend()

# %%
plot('dc for 4.9', 'dc for 6.8')

# %%
train_features.describe().transpose()
# Out:
#                count        mean         std          min         25%  \
# vx           62117.0   42.229020  373.868198 -1234.874100 -228.986040
# vy           62117.0  -12.574343  382.696279 -1571.376600 -257.360050
# vz           62117.0  106.914053  383.604488 -1311.024700 -138.588300
# dc for 4.9   62117.0   -0.107276    0.020800    -0.127820   -0.124461
# dc for 6.8   62117.0   -0.060367    0.020911    -0.099572   -0.076238
# dc for 8.7   62117.0   -0.035466    0.018610    -0.083351   -0.048516
# dc for 10.6  62117.0   -0.022784    0.016990    -0.072824   -0.034563
# dc for 12.4  62117.0   -0.015353    0.015173    -0.065159   -0.025772
# dc for 14.3  62117.0   -0.010160    0.013557    -0.059339   -0.019314
# dc for 16.2  62117.0   -0.006136    0.012283    -0.050433   -0.014366
# dc for 18.1  62117.0   -0.002858    0.011201    -0.042834   -0.010436
# dc for 20.0  62117.0   -0.000174    0.010211    -0.035228   -0.007150
#
#                     50%         75%          max
# vx            36.624660  299.263850  1362.093800
# vy            -0.613530  247.605530  1185.835400
# vz           112.977980  367.935420  1349.211900
# dc for 4.9    -0.113865   -0.095517     0.007852
# dc for 6.8    -0.061751   -0.047069     0.037616
# dc for 8.7    -0.036501   -0.022995     0.043554
# dc for 10.6   -0.022979   -0.011343     0.042347
# dc for 12.4   -0.015216   -0.004849     0.043754
# dc for 14.3   -0.010133   -0.000797     0.034524
# dc for 16.2   -0.006329    0.002191     0.033084
# dc for 18.1   -0.003360    0.004863     0.034125
# dc for 20.0   -0.000735    0.006938     0.033423

# %%
# todo : vx^2 + vy^2 + vz^2 = v^2
v_squared_train = train_features['vx'] ** 2 + train_features['vy'] ** 2 + train_features['vz'] ** 2
v_squared_test = test_features['vx'] ** 2 + test_features['vy'] ** 2 + test_features['vz'] ** 2
v_squared_train.describe()
# Out:
# count    6.211700e+04
# mean     4.467513e+05
# std      3.464878e+05
# min      3.289182e+02
# 25%      1.844948e+05
# 50%      3.643040e+05
# 75%      6.221219e+05
# max      2.871873e+06
# dtype: float64

# %%
train_features = train_features.drop(['vx' , 'vy', 'vz'], axis = 1)
test_features = test_features.drop(['vx' , 'vy', 'vz'], axis = 1)
train_features
# Out:
#        dc for 4.9  dc for 6.8  dc for 8.7  dc for 10.6  dc for 12.4  \
# 31263   -0.127820   -0.090530   -0.065840    -0.052262    -0.037336
# 82485   -0.107146   -0.074293   -0.060065    -0.048727    -0.037005
# 77144   -0.018766    0.003586    0.001967    -0.001229    -0.005275
# 87039   -0.086214   -0.059515   -0.039248    -0.014078    -0.004392
# 3420    -0.124202   -0.080419   -0.060717    -0.056493    -0.046442
# ...           ...         ...         ...          ...          ...
# 95110   -0.123686   -0.083724   -0.049680    -0.029687    -0.011135
# 64791   -0.112832   -0.049208   -0.043440    -0.040368    -0.039100
# 81819   -0.037114   -0.017220   -0.011772    -0.015987    -0.015058
# 31327   -0.111798   -0.059126   -0.018943    -0.004041     0.001736
# 22482   -0.069675   -0.015373    0.011980     0.008549     0.008007
#
#        dc for 14.3  dc for 16.2  dc for 18.1  dc for 20.0
# 31263    -0.027484    -0.017832    -0.014069    -0.008906
# 82485    -0.033983    -0.027364    -0.021877    -0.015933
# 77144    -0.007668    -0.002286    -0.001047    -0.001172
# 87039     0.001029     0.000625    -0.001057     0.001020
# 3420     -0.042751    -0.033471    -0.024471    -0.016256
# ...            ...          ...          ...          ...
# 95110    -0.004315     0.008704     0.021016     0.023226
# 64791    -0.038089    -0.029257    -0.018438    -0.006550
# 81819    -0.011020    -0.007846    -0.006516    -0.006071
# 31327    -0.000323     0.000006     0.004745     0.004171
# 22482     0.010436     0.017331     0.016739     0.017807
#
# [62117 rows x 9 columns]

# %%
v_squared_train
# Out:
# 31263    239795.819148
# 82485    298205.597516
# 77144    565898.238239
# 87039    938088.266089
# 3420     264295.393841
#              ...
# 95110    240565.641497
# 64791    279105.346986
# 81819    265885.736632
# 31327    191791.267116
# 22482     66862.346887
# Length: 62117, dtype: float64

# %%
train_features['v^2'] = v_squared_train
test_features['v^2'] = v_squared_test

# %%
train_features
# Out:
#        dc for 4.9  dc for 6.8  dc for 8.7  dc for 10.6  dc for 12.4  \
# 31263   -0.127820   -0.090530   -0.065840    -0.052262    -0.037336
# 82485   -0.107146   -0.074293   -0.060065    -0.048727    -0.037005
# 77144   -0.018766    0.003586    0.001967    -0.001229    -0.005275
# 87039   -0.086214   -0.059515   -0.039248    -0.014078    -0.004392
# 3420    -0.124202   -0.080419   -0.060717    -0.056493    -0.046442
# ...           ...         ...         ...          ...          ...
# 95110   -0.123686   -0.083724   -0.049680    -0.029687    -0.011135
# 64791   -0.112832   -0.049208   -0.043440    -0.040368    -0.039100
# 81819   -0.037114   -0.017220   -0.011772    -0.015987    -0.015058
# 31327   -0.111798   -0.059126   -0.018943    -0.004041     0.001736
# 22482   -0.069675   -0.015373    0.011980     0.008549     0.008007
#
#        dc for 14.3  dc for 16.2  dc for 18.1  dc for 20.0            v^2
# 31263    -0.027484    -0.017832    -0.014069    -0.008906  239795.819148
# 82485    -0.033983    -0.027364    -0.021877    -0.015933  298205.597516
# 77144    -0.007668    -0.002286    -0.001047    -0.001172  565898.238239
# 87039     0.001029     0.000625    -0.001057     0.001020  938088.266089
# 3420     -0.042751    -0.033471    -0.024471    -0.016256  264295.393841
# ...            ...          ...          ...          ...            ...
# 95110    -0.004315     0.008704     0.021016     0.023226  240565.641497
# 64791    -0.038089    -0.029257    -0.018438    -0.006550  279105.346986
# 81819    -0.011020    -0.007846    -0.006516    -0.006071  265885.736632
# 31327    -0.000323     0.000006     0.004745     0.004171  191791.267116
# 22482     0.010436     0.017331     0.016739     0.017807   66862.346887
#
# [62117 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(train_features)
train = scaler.transform(train_features)
test = scaler.transform(test_features)

# %%
train.shape
# Out:
# (62117, 10)

# %%
train
# Out:
# array([[-0.988, -1.442, -1.632, ..., -1.001, -0.855, -0.597],
#        [ 0.006, -0.666, -1.322, ..., -1.698, -1.543, -0.429],
#        [ 4.255,  3.058,  2.012, ...,  0.162, -0.098,  0.344],
#        ...,
#        [ 3.373,  2.063,  1.273, ..., -0.327, -0.578, -0.522],
#        [-0.217,  0.059,  0.888, ...,  0.679,  0.425, -0.736],
#        [ 1.808,  2.152,  2.55 , ...,  1.75 ,  1.761, -1.096]])

# %%
from keras import backend as K
def coeff_determination(y_true, y_pred):
    from keras import backend as K
    SS_res = K.sum(K.square(y_true - y_pred))
    SS_tot = K.sum(K.square(y_true - K.mean(y_true)))
    return (1 - SS_res/(SS_tot + K.epsilon()))

loss = keras.losses.MeanAbsoluteError()  # MeanSquaredError
learning_rate = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate= 0.001,
    decay_steps=100000,
    decay_rate=0.001
)
optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

dnn_model = keras.Sequential([
    layers.Dense(128, input_shape=(10,), activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(units=1)
])

dnn_model.compile(
    optimizer=optimizer,
    loss=loss,
    metrics=[coeff_determination],
)

# %%
scaler = StandardScaler()
train_labels = train_labels.values.reshape(-1, 1)
test_labels = test_labels.values.reshape(-1, 1)
scaler.fit(train_labels)
train_labels_normalized = scaler.transform(train_labels)
test_labels_normalized = scaler.transform(test_labels)

# %%
history = dnn_model.fit(
    train, train_labels_normalized,
    epochs=400,
    verbose=1,
    batch_size=128,
    # Calculate validation results on 20% of the training data
    validation_split = 0.2,
    shuffle=True
)
# Out:
# Epoch 1/400
# 389/389 [==============================] - 6s 13ms/step - loss: 0.5770 - coeff_determination: 0.1847 - val_loss: 0.5720 - val_coeff_determination: 0.2124
# Epoch 2/400
# 389/389 [==============================] - 6s 16ms/step - loss: 0.5592 - coeff_determination: 0.2306 - val_loss: 0.5599 - val_coeff_determination: 0.2339
# Epoch 3/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.5515 - coeff_determination: 0.2456 - val_loss: 0.5565 - val_coeff_determination: 0.2305
# Epoch 4/400
# 389/389 [==============================] - 5s 13ms/step - loss: 0.5473 - coeff_determination: 0.2521 - val_loss: 0.5519 - val_coeff_determination: 0.2576
# Epoch 5/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.5425 - coeff_determination: 0.2602 - val_loss: 0.5416 - val_coeff_determination: 0.2902
# Epoch 6/400
# 389/389 [==============================] - 5s 13ms/step - loss: 0.5381 - coeff_determination: 0.2686 - val_loss: 0.5308 - val_coeff_determination: 0.3079
# Epoch 7/400
# 389/389 [==============================] - 6s 14ms/step - loss: 0.5359 - coeff_determination: 0.2693 - val_loss: 0.5319 - val_coeff_determination: 0.2994
# Epoch 8/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.5331 - coeff_determination: 0.2765 - val_loss: 0.5282 - val_coeff_determination: 0.3002
# Epoch 9/400
# 389/389 [==============================] - 3s 6ms/step - loss: 0.5303 - coeff_determination: 0.2822 - val_loss: 0.5309 - val_coeff_determination: 0.2948
# Epoch 10/400
# 389/389 [==============================] - 2s 6ms/step - loss: 0.5275 - coeff_determination: 0.2891 - val_loss: 0.5235 - val_coeff_determination: 0.3126
# Epoch 11/400
# 389/389 [==============================] - 3s 7ms/step - loss: 0.5254 - coeff_determination: 0.2897 - val_loss: 0.5248 - val_coeff_determination: 0.3107
# Epoch 12/400
# 389/389 [==============================] - 3s 7ms/step - loss: 0.5227 - coeff_determination: 0.2931 - val_loss: 0.5165 - val_coeff_determination: 0.3212
# Epoch 13/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5211 - coeff_determination: 0.2948 - val_loss: 0.5148 - val_coeff_determination: 0.3125
# Epoch 14/400
# 389/389 [==============================] - 3s 7ms/step - loss: 0.5180 - coeff_determination: 0.3034 - val_loss: 0.5129 - val_coeff_determination: 0.3136
# Epoch 15/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5145 - coeff_determination: 0.3034 - val_loss: 0.5092 - val_coeff_determination: 0.3210
# Epoch 16/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5134 - coeff_determination: 0.3061 - val_loss: 0.5106 - val_coeff_determination: 0.3237
# Epoch 17/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5105 - coeff_determination: 0.3135 - val_loss: 0.5055 - val_coeff_determination: 0.3347
# Epoch 18/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5075 - coeff_determination: 0.3190 - val_loss: 0.5039 - val_coeff_determination: 0.3360
# Epoch 19/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5070 - coeff_determination: 0.3196 - val_loss: 0.5046 - val_coeff_determination: 0.3308
# Epoch 20/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.5065 - coeff_determination: 0.3165 - val_loss: 0.5034 - val_coeff_determination: 0.3392
# Epoch 21/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5037 - coeff_determination: 0.3210 - val_loss: 0.5031 - val_coeff_determination: 0.3231
# Epoch 22/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5036 - coeff_determination: 0.3216 - val_loss: 0.4948 - val_coeff_determination: 0.3452
# Epoch 23/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.5007 - coeff_determination: 0.3237 - val_loss: 0.4947 - val_coeff_determination: 0.3397
# Epoch 24/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4977 - coeff_determination: 0.3314 - val_loss: 0.4970 - val_coeff_determination: 0.3268
# Epoch 25/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4976 - coeff_determination: 0.3305 - val_loss: 0.4947 - val_coeff_determination: 0.3405
# Epoch 26/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4978 - coeff_determination: 0.3331 - val_loss: 0.4945 - val_coeff_determination: 0.3436
# Epoch 27/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4948 - coeff_determination: 0.3352 - val_loss: 0.4910 - val_coeff_determination: 0.3442
# Epoch 28/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4953 - coeff_determination: 0.3309 - val_loss: 0.4920 - val_coeff_determination: 0.3490
# Epoch 29/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4935 - coeff_determination: 0.3359 - val_loss: 0.4892 - val_coeff_determination: 0.3492
# Epoch 30/400
# 389/389 [==============================] - 3s 7ms/step - loss: 0.4909 - coeff_determination: 0.3350 - val_loss: 0.4882 - val_coeff_determination: 0.3521
# Epoch 31/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4903 - coeff_determination: 0.3398 - val_loss: 0.4939 - val_coeff_determination: 0.3391
# Epoch 32/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4901 - coeff_determination: 0.3387 - val_loss: 0.4886 - val_coeff_determination: 0.3508
# Epoch 33/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4889 - coeff_determination: 0.3412 - val_loss: 0.4870 - val_coeff_determination: 0.3362
# Epoch 34/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4890 - coeff_determination: 0.3370 - val_loss: 0.4888 - val_coeff_determination: 0.3518
# Epoch 35/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4871 - coeff_determination: 0.3444 - val_loss: 0.4855 - val_coeff_determination: 0.3499
# Epoch 36/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4863 - coeff_determination: 0.3432 - val_loss: 0.4822 - val_coeff_determination: 0.3590
# Epoch 37/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4848 - coeff_determination: 0.3442 - val_loss: 0.4833 - val_coeff_determination: 0.3496
# Epoch 38/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4853 - coeff_determination: 0.3432 - val_loss: 0.4813 - val_coeff_determination: 0.3514
# Epoch 39/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4851 - coeff_determination: 0.3409 - val_loss: 0.4821 - val_coeff_determination: 0.3632
# Epoch 40/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4811 - coeff_determination: 0.3493 - val_loss: 0.4824 - val_coeff_determination: 0.3580
# Epoch 41/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4824 - coeff_determination: 0.3467 - val_loss: 0.4826 - val_coeff_determination: 0.3516
# Epoch 42/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4788 - coeff_determination: 0.3577 - val_loss: 0.4814 - val_coeff_determination: 0.3625
# Epoch 43/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4799 - coeff_determination: 0.3532 - val_loss: 0.4806 - val_coeff_determination: 0.3542
# Epoch 44/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4796 - coeff_determination: 0.3496 - val_loss: 0.4784 - val_coeff_determination: 0.3520
# Epoch 45/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.4765 - coeff_determination: 0.3606 - val_loss: 0.4779 - val_coeff_determination: 0.3502
# Epoch 46/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4789 - coeff_determination: 0.3488 - val_loss: 0.4748 - val_coeff_determination: 0.3670
# Epoch 47/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4776 - coeff_determination: 0.3496 - val_loss: 0.4755 - val_coeff_determination: 0.3715
# Epoch 48/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4773 - coeff_determination: 0.3599 - val_loss: 0.4762 - val_coeff_determination: 0.3550
# Epoch 49/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4754 - coeff_determination: 0.3584 - val_loss: 0.4742 - val_coeff_determination: 0.3668
# Epoch 50/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4756 - coeff_determination: 0.3559 - val_loss: 0.4765 - val_coeff_determination: 0.3545
# Epoch 51/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4722 - coeff_determination: 0.3650 - val_loss: 0.4739 - val_coeff_determination: 0.3585
# Epoch 52/400
# 389/389 [==============================] - 4s 10ms/step - loss: 0.4738 - coeff_determination: 0.3607 - val_loss: 0.4751 - val_coeff_determination: 0.3593
# Epoch 53/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4751 - coeff_determination: 0.3566 - val_loss: 0.4736 - val_coeff_determination: 0.3655
# Epoch 54/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4723 - coeff_determination: 0.3601 - val_loss: 0.4731 - val_coeff_determination: 0.3628
# Epoch 55/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4725 - coeff_determination: 0.3615 - val_loss: 0.4725 - val_coeff_determination: 0.3549
# Epoch 56/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4725 - coeff_determination: 0.3597 - val_loss: 0.4722 - val_coeff_determination: 0.3642
# Epoch 57/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4702 - coeff_determination: 0.3673 - val_loss: 0.4693 - val_coeff_determination: 0.3622
# Epoch 58/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.4688 - coeff_determination: 0.3622 - val_loss: 0.4694 - val_coeff_determination: 0.3546
# Epoch 59/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4686 - coeff_determination: 0.3656 - val_loss: 0.4708 - val_coeff_determination: 0.3663
# Epoch 60/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4672 - coeff_determination: 0.3637 - val_loss: 0.4710 - val_coeff_determination: 0.3597
# Epoch 61/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4690 - coeff_determination: 0.3627 - val_loss: 0.4677 - val_coeff_determination: 0.3620
# Epoch 62/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4661 - coeff_determination: 0.3713 - val_loss: 0.4673 - val_coeff_determination: 0.3631
# Epoch 63/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4649 - coeff_determination: 0.3703 - val_loss: 0.4668 - val_coeff_determination: 0.3678
# Epoch 64/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4667 - coeff_determination: 0.3669 - val_loss: 0.4705 - val_coeff_determination: 0.3700
# Epoch 65/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4664 - coeff_determination: 0.3676 - val_loss: 0.4685 - val_coeff_determination: 0.3644
# Epoch 66/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4648 - coeff_determination: 0.3656 - val_loss: 0.4685 - val_coeff_determination: 0.3722
# Epoch 67/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4663 - coeff_determination: 0.3680 - val_loss: 0.4660 - val_coeff_determination: 0.3653
# Epoch 68/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4644 - coeff_determination: 0.3686 - val_loss: 0.4666 - val_coeff_determination: 0.3666
# Epoch 69/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4637 - coeff_determination: 0.3691 - val_loss: 0.4665 - val_coeff_determination: 0.3631
# Epoch 70/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4636 - coeff_determination: 0.3722 - val_loss: 0.4645 - val_coeff_determination: 0.3707
# Epoch 71/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4651 - coeff_determination: 0.3660 - val_loss: 0.4644 - val_coeff_determination: 0.3735
# Epoch 72/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.4625 - coeff_determination: 0.3764 - val_loss: 0.4639 - val_coeff_determination: 0.3772
# Epoch 73/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4621 - coeff_determination: 0.3785 - val_loss: 0.4653 - val_coeff_determination: 0.3720
# Epoch 74/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4629 - coeff_determination: 0.3716 - val_loss: 0.4654 - val_coeff_determination: 0.3741
# Epoch 75/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4627 - coeff_determination: 0.3719 - val_loss: 0.4654 - val_coeff_determination: 0.3704
# Epoch 76/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4618 - coeff_determination: 0.3725 - val_loss: 0.4649 - val_coeff_determination: 0.3725
# Epoch 77/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4624 - coeff_determination: 0.3726 - val_loss: 0.4646 - val_coeff_determination: 0.3774
# Epoch 78/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4614 - coeff_determination: 0.3760 - val_loss: 0.4654 - val_coeff_determination: 0.3703
# Epoch 79/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.4612 - coeff_determination: 0.3801 - val_loss: 0.4640 - val_coeff_determination: 0.3762
# Epoch 80/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4604 - coeff_determination: 0.3795 - val_loss: 0.4644 - val_coeff_determination: 0.3740
# Epoch 81/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4594 - coeff_determination: 0.3786 - val_loss: 0.4612 - val_coeff_determination: 0.3780
# Epoch 82/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4600 - coeff_determination: 0.3794 - val_loss: 0.4623 - val_coeff_determination: 0.3734
# Epoch 83/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4591 - coeff_determination: 0.3798 - val_loss: 0.4624 - val_coeff_determination: 0.3718
# Epoch 84/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4587 - coeff_determination: 0.3785 - val_loss: 0.4625 - val_coeff_determination: 0.3758
# Epoch 85/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4595 - coeff_determination: 0.3780 - val_loss: 0.4617 - val_coeff_determination: 0.3816
# Epoch 86/400
# 389/389 [==============================] - 4s 10ms/step - loss: 0.4599 - coeff_determination: 0.3755 - val_loss: 0.4604 - val_coeff_determination: 0.3766
# Epoch 87/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4583 - coeff_determination: 0.3770 - val_loss: 0.4604 - val_coeff_determination: 0.3776
# Epoch 88/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4580 - coeff_determination: 0.3799 - val_loss: 0.4614 - val_coeff_determination: 0.3806
# Epoch 89/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4582 - coeff_determination: 0.3809 - val_loss: 0.4612 - val_coeff_determination: 0.3766
# Epoch 90/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4576 - coeff_determination: 0.3841 - val_loss: 0.4616 - val_coeff_determination: 0.3764
# Epoch 91/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4600 - coeff_determination: 0.3768 - val_loss: 0.4602 - val_coeff_determination: 0.3734
# Epoch 92/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.4569 - coeff_determination: 0.3832 - val_loss: 0.4604 - val_coeff_determination: 0.3751
# Epoch 93/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4558 - coeff_determination: 0.3850 - val_loss: 0.4615 - val_coeff_determination: 0.3752
# Epoch 94/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4571 - coeff_determination: 0.3852 - val_loss: 0.4597 - val_coeff_determination: 0.3776
# Epoch 95/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4568 - coeff_determination: 0.3821 - val_loss: 0.4593 - val_coeff_determination: 0.3805
# Epoch 96/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4565 - coeff_determination: 0.3796 - val_loss: 0.4607 - val_coeff_determination: 0.3784
# Epoch 97/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4563 - coeff_determination: 0.3866 - val_loss: 0.4609 - val_coeff_determination: 0.3796
# Epoch 98/400
# 389/389 [==============================] - 3s 8ms/step - loss: 0.4565 - coeff_determination: 0.3832 - val_loss: 0.4602 - val_coeff_determination: 0.3800
# Epoch 99/400
# 389/389 [==============================] - 8s 21ms/step - loss: 0.4566 - coeff_determination: 0.3808 - val_loss: 0.4607 - val_coeff_determination: 0.3818
# Epoch 100/400
# 389/389 [==============================] - 15s 39ms/step - loss: 0.4559 - coeff_determination: 0.3836 - val_loss: 0.4601 - val_coeff_determination: 0.3809
# Epoch 101/400
# 389/389 [==============================] - 12s 31ms/step - loss: 0.4570 - coeff_determination: 0.3801 - val_loss: 0.4589 - val_coeff_determination: 0.3823
# Epoch 102/400
# 389/389 [==============================] - 14s 36ms/step - loss: 0.4579 - coeff_determination: 0.3814 - val_loss: 0.4590 - val_coeff_determination: 0.3771eterm
# Epoch 103/400
# 389/389 [==============================] - 12s 30ms/step - loss: 0.4551 - coeff_determination: 0.3833 - val_loss: 0.4582 - val_coeff_determination: 0.3818
# Epoch 104/400
# 389/389 [==============================] - 10s 25ms/step - loss: 0.4554 - coeff_determination: 0.3868 - val_loss: 0.4590 - val_coeff_determination: 0.3821
# Epoch 105/400
# 389/389 [==============================] - 12s 30ms/step - loss: 0.4568 - coeff_determination: 0.3823 - val_loss: 0.4580 - val_coeff_determination: 0.3793 0.4 - ETA: 2s - loss: 0.4586 - c
# Epoch 106/400
# 389/389 [==============================] - 7s 19ms/step - loss: 0.4539 - coeff_determination: 0.3857 - val_loss: 0.4576 - val_coeff_determination: 0.3794
# Epoch 107/400
# 389/389 [==============================] - 7s 19ms/step - loss: 0.4568 - coeff_determination: 0.3827 - val_loss: 0.4576 - val_coeff_determination: 0.3814
# Epoch 108/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.4539 - coeff_determination: 0.3891 - val_loss: 0.4574 - val_coeff_determination: 0.3780
# Epoch 109/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4544 - coeff_determination: 0.3869 - val_loss: 0.4574 - val_coeff_determination: 0.3827
# Epoch 110/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.4544 - coeff_determination: 0.3856 - val_loss: 0.4579 - val_coeff_determination: 0.3824
# Epoch 111/400
# 389/389 [==============================] - 4s 9ms/step - loss: 0.4550 - coeff_determination: 0.3910 - val_loss: 0.4581 - val_coeff_determination: 0.3817
# Epoch 112/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4533 - coeff_determination: 0.3949 - val_loss: 0.4567 - val_coeff_determination: 0.3831
# Epoch 113/400
# 389/389 [==============================] - 3s 9ms/step - loss: 0.4542 - coeff_determination: 0.3841 - val_loss: 0.4571 - val_coeff_determination: 0.3830
# Epoch 114/400
# 389/389 [==============================] - 4s 10ms/step - loss: 0.4547 - coeff_determination: 0.3881 - val_loss: 0.4569 - val_coeff_determination: 0.3822
# Epoch 115/400
# 389/389 [==============================] - 5s 14ms/step - loss: 0.4539 - coeff_determination: 0.3841 - val_loss: 0.4574 - val_coeff_determination: 0.3795
# Epoch 116/400
# 389/389 [==============================] - 5s 13ms/step - loss: 0.4529 - coeff_determination: 0.3908 - val_loss: 0.4573 - val_coeff_determination: 0.3819
# Epoch 117/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4536 - coeff_determination: 0.3870 - val_loss: 0.4583 - val_coeff_determination: 0.3809
# Epoch 118/400
# 389/389 [==============================] - 5s 13ms/step - loss: 0.4540 - coeff_determination: 0.3888 - val_loss: 0.4579 - val_coeff_determination: 0.3779
# Epoch 119/400
# 389/389 [==============================] - 5s 13ms/step - loss: 0.4530 - coeff_determination: 0.3860 - val_loss: 0.4571 - val_coeff_determination: 0.3827
# Epoch 120/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4544 - coeff_determination: 0.3863 - val_loss: 0.4572 - val_coeff_determination: 0.3782
# Epoch 121/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4535 - coeff_determination: 0.3884 - val_loss: 0.4574 - val_coeff_determination: 0.3823
# Epoch 122/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4514 - coeff_determination: 0.3942 - val_loss: 0.4583 - val_coeff_determination: 0.3794
# Epoch 123/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4537 - coeff_determination: 0.3927 - val_loss: 0.4579 - val_coeff_determination: 0.3800
# Epoch 124/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4531 - coeff_determination: 0.3858 - val_loss: 0.4573 - val_coeff_determination: 0.3811
# Epoch 125/400
# 389/389 [==============================] - 5s 13ms/step - loss: 0.4540 - coeff_determination: 0.3870 - val_loss: 0.4573 - val_coeff_determination: 0.3801
# Epoch 126/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4523 - coeff_determination: 0.3886 - val_loss: 0.4567 - val_coeff_determination: 0.3810
# Epoch 127/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4523 - coeff_determination: 0.3873 - val_loss: 0.4569 - val_coeff_determination: 0.3815
# Epoch 128/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4497 - coeff_determination: 0.3939 - val_loss: 0.4569 - val_coeff_determination: 0.3803
# Epoch 129/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4516 - coeff_determination: 0.3904 - val_loss: 0.4565 - val_coeff_determination: 0.3812
# Epoch 130/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4524 - coeff_determination: 0.3909 - val_loss: 0.4568 - val_coeff_determination: 0.3823
# Epoch 131/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4527 - coeff_determination: 0.3912 - val_loss: 0.4566 - val_coeff_determination: 0.3823
# Epoch 132/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4508 - coeff_determination: 0.3918 - val_loss: 0.4566 - val_coeff_determination: 0.3824
# Epoch 133/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4510 - coeff_determination: 0.3938 - val_loss: 0.4564 - val_coeff_determination: 0.3823
# Epoch 134/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4523 - coeff_determination: 0.3872 - val_loss: 0.4565 - val_coeff_determination: 0.3838
# Epoch 135/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4515 - coeff_determination: 0.3929 - val_loss: 0.4569 - val_coeff_determination: 0.3839
# Epoch 136/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4536 - coeff_determination: 0.3870 - val_loss: 0.4566 - val_coeff_determination: 0.3808
# Epoch 137/400
# 389/389 [==============================] - 5s 13ms/step - loss: 0.4541 - coeff_determination: 0.3835 - val_loss: 0.4564 - val_coeff_determination: 0.3827
# Epoch 138/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4522 - coeff_determination: 0.3906 - val_loss: 0.4566 - val_coeff_determination: 0.3819
# Epoch 139/400
# 389/389 [==============================] - 5s 12ms/step - loss: 0.4495 - coeff_determination: 0.3980 - val_loss: 0.4565 - val_coeff_determination: 0.3820
# Epoch 140/400
# 389/389 [==============================] - 5s 14ms/step - loss: 0.4533 - coeff_determination: 0.3882 - val_loss: 0.4562 - val_coeff_determination: 0.3802
# Epoch 141/400
# 389/389 [==============================] - 5s 13ms/step - loss: 0.4533 - coeff_determination: 0.3825 - val_loss: 0.4559 - val_coeff_determination: 0.3814
# Epoch 142/400
# 389/389 [==============================] - 6s 14ms/step - loss: 0.4516 - coeff_determination: 0.3892 - val_loss: 0.4564 - val_coeff_determination: 0.3830
# Epoch 143/400
# 389/389 [==============================] - 6s 16ms/step - loss: 0.4506 - coeff_determination: 0.3959 - val_loss: 0.4566 - val_coeff_determination: 0.3822
# Epoch 144/400
#  53/389 [===>..........................] - ETA: 7s - loss: 0.4656 - coeff_determination: 0.3398
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18700/3397230698.py in <module>
# ----> 1 history = dnn_model.fit(
#       2     train, train_labels_normalized,
#       3     epochs=400,
#       4     verbose=1,
#       5     batch_size=128,
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/lib/python3.9/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1219               logs = tmp_logs  # No error, now safe to assign to logs.
#    1220               end_step = step + data_handler.step_increment
# -> 1221               callbacks.on_train_batch_end(end_step, logs)
#    1222               if self.stop_training:
#    1223                 break
#
# ~/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     434     """
#     435     if self._should_call_train_batch_hooks:
# --> 436       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     437
#     438   def on_test_batch_begin(self, batch, logs=None):
#
# ~/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     293       self._call_batch_begin_hook(mode, batch, logs)
#     294     elif hook == 'end':
# --> 295       self._call_batch_end_hook(mode, batch, logs)
#     296     else:
#     297       raise ValueError(
#
# ~/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     314       self._batch_times.append(batch_time)
#     315
# --> 316     self._call_batch_hook_helper(hook_name, batch, logs)
#     317
#     318     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# ~/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     352     for callback in self.callbacks:
#     353       hook = getattr(callback, hook_name)
# --> 354       hook(batch, logs)
#     355
#     356     if self._check_timing:
#
# ~/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1030
#    1031   def on_train_batch_end(self, batch, logs=None):
# -> 1032     self._batch_update_progbar(batch, logs)
#    1033
#    1034   def on_test_batch_end(self, batch, logs=None):
#
# ~/anaconda3/lib/python3.9/site-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1102     if self.verbose == 1:
#    1103       # Only block async when verbose = 1.
# -> 1104       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1105       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1106
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
# --> 554   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     555
#     556
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/anaconda3/lib/python3.9/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     867
#     868   return pack_sequence_as(
# --> 869       structure[0], [func(*x) for x in entries],
#     870       expand_composites=expand_composites)
#     871
#
# ~/anaconda3/lib/python3.9/site-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     549     if isinstance(t, tf.Tensor):
#     550       x = t.numpy()
# --> 551       return x.item() if np.ndim(x) == 0 else x
#     552     return t  # Don't turn ragged or sparse tensors to NumPy.
#     553
#
# KeyboardInterrupt:

# %%
def plot_r2(history):
    plt.plot(history.history['coeff_determination'], label = 'coeff_determination')
    plt.plot(history.history['val_coeff_determination'], label='val_coeff_determination')
    # plt.ylim([1200, 1400])
    plt.xlabel('Epoch')
    plt.ylabel('Error [halo_mass]')
    plt.legend()
    plt.grid(True)

plot_r2(history)

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label = 'loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    # plt.ylim([1200, 1400])
    plt.xlabel('Epoch')
    plt.ylabel('Error [halo_mass]')
    plt.legend()
    plt.grid(True)

plot_loss(history)

# %% [markdown]
# testing on 0.01 of the data After training

# %%
dnn_model.evaluate(
    test,
    test_labels_normalized, verbose = 1
)
# Out:
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4624 - coeff_determination: 0.3740
# [0.4623904824256897, 0.374001145362854]

# %% [markdown]
# Tuning The Model

# %%
from kerastuner.tuners import RandomSearch

# %%
dataset_v = dataset.drop(['vx', 'vy', 'vz', 'id', 'haloID'], axis=1)
dataset_v['v^2'] = dataset['vx'] ** 2 + dataset['vy'] ** 2 + dataset['vz'] ** 2
train_dataset, test_dataset = train_test_split(dataset_v, test_size=0.2, random_state= 43)

print(dataset.shape, train_dataset.shape, test_dataset.shape)
train_dataset.describe().transpose()
# Out:
# (62745, 15) (50196, 11) (12549, 11)
#                count           mean            std          min  \
# halo_mass    50196.0    4176.630528    2958.632079  1504.000000
# dc for 4.9   50196.0      -0.107220       0.020857    -0.127820
# dc for 6.8   50196.0      -0.060340       0.020944    -0.099572
# dc for 8.7   50196.0      -0.035446       0.018619    -0.083351
# dc for 10.6  50196.0      -0.022769       0.016995    -0.072824
# dc for 12.4  50196.0      -0.015343       0.015168    -0.065159
# dc for 14.3  50196.0      -0.010158       0.013543    -0.058720
# dc for 16.2  50196.0      -0.006134       0.012262    -0.049957
# dc for 18.1  50196.0      -0.002856       0.011179    -0.042834
# dc for 20.0  50196.0      -0.000176       0.010198    -0.035228
# v^2          50196.0  446780.709944  346562.180218   328.918184
#
#                        25%            50%            75%           max
# halo_mass      2221.000000    3182.000000    5008.000000  3.125200e+04
# dc for 4.9       -0.124461      -0.113865      -0.095259  7.852109e-03
# dc for 6.8       -0.076238      -0.061654      -0.046972  3.401874e-02
# dc for 8.7       -0.048469      -0.036477      -0.022995  4.290240e-02
# dc for 10.6      -0.034537      -0.022953      -0.011291  4.234717e-02
# dc for 12.4      -0.025724      -0.015216      -0.004833  4.375428e-02
# dc for 14.3      -0.019314      -0.010123      -0.000818  3.452373e-02
# dc for 16.2      -0.014337      -0.006322       0.002170  3.287723e-02
# dc for 18.1      -0.010410      -0.003365       0.004834  3.412503e-02
# dc for 20.0      -0.007147      -0.000747       0.006912  3.342270e-02
# v^2          184395.663924  364076.729785  622538.008004  2.871873e+06

# %% [markdown]
# Normalizing the Data

# %%
train_labels = train_dataset.pop('halo_mass').values.reshape(-1, 1)
train_features = train_dataset.copy()
test_labels = test_dataset.pop('halo_mass').values.reshape(-1, 1)
test_features = test_dataset

# %%
scaler = StandardScaler()
scaler.fit(train_features)
train_features_normalized = scaler.transform(train_features)
test_features_normalized = scaler.transform(test_features)
scaler.fit(train_labels)
train_labels_normalized = scaler.transform(train_labels)
test_labels_normalized = scaler.transform(test_labels)

# %%
scaler = StandardScaler()
scaler.fit(train_features)
train = scaler.transform(train_features)
test = scaler.transform(test_features)

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step = 32),
                                            activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
            loss = 'mean_absolute_error',
            metrics=['mean_absolute_error', coeff_determination]
    )
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='mean_absolute_error',
    max_trials=5,
    executions_per_trial=3,
    project_name='Density Contrast Parameters'
)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./Density Contrast Parameters/oracle.json
# INFO:tensorflow:Reloading Tuner from ./Density Contrast Parameters/tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 22
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_15 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_16 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_17 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_18 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}
# units_19 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': None}

# %%
print(test_features_normalized.transpose().shape)
print(test_labels_normalized.shape)
# Out:
# (10, 12549)
# (12549, 1)

# %%
tuner.search(train_features_normalized, train_labels_normalized,
             epochs=5,
             validation_data = (test_features_normalized, test_labels_normalized))
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./Density Contrast Parameters
# Showing 10 best trials
# Objective(name='mean_absolute_error', direction='min')
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 256
# units_1: 64
# learning_rate: 0.001
# units_2: 256
# units_3: 352
# units_4: 448
# units_5: 480
# units_6: 320
# units_7: 64
# units_8: 512
# units_9: 320
# units_10: 512
# units_11: 320
# units_12: 64
# units_13: 416
# units_14: 448
# units_15: 480
# units_16: 128
# units_17: 64
# units_18: 32
# Score: 0.518230676651001
# Trial summary
# Hyperparameters:
# num_layers: 10
# units_0: 288
# units_1: 64
# learning_rate: 0.0001
# units_2: 32
# units_3: 32
# units_4: 32
# units_5: 32
# units_6: 32
# units_7: 32
# units_8: 32
# units_9: 32
# Score: 0.5269128481547037
# Trial summary
# Hyperparameters:
# num_layers: 19
# units_0: 128
# units_1: 160
# learning_rate: 0.001
# units_2: 480
# units_3: 224
# units_4: 352
# units_5: 32
# units_6: 64
# units_7: 448
# units_8: 64
# units_9: 512
# units_10: 32
# units_11: 32
# units_12: 32
# units_13: 32
# units_14: 32
# units_15: 32
# units_16: 32
# units_17: 32
# units_18: 32
# Score: 0.5309096773465475
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 416
# units_1: 128
# learning_rate: 0.01
# units_2: 128
# units_3: 480
# units_4: 96
# units_5: 64
# units_6: 320
# units_7: 512
# units_8: 96
# units_9: 320
# units_10: 320
# units_11: 192
# units_12: 96
# units_13: 512
# units_14: 288
# units_15: 512
# units_16: 160
# units_17: 256
# units_18: 320
# units_19: 384
# Score: 0.5550044775009155
# Trial summary
# Hyperparameters:
# num_layers: 20
# units_0: 256
# units_1: 96
# learning_rate: 0.01
# units_2: 192
# units_3: 320
# units_4: 384
# units_5: 32
# units_6: 192
# units_7: 384
# units_8: 96
# units_9: 320
# units_10: 448
# units_11: 32
# units_12: 384
# units_13: 224
# units_14: 288
# units_15: 64
# units_16: 160
# units_17: 384
# units_18: 448
# units_19: 32
# Score: 0.6539330085118612

# %% [markdown]
# The Best Values for this model are:<br>
# learning_rate = 0.001 <br>
# loss = 0.518 <br>

# %% [markdown]
# Now we can use the model to draw what the predicted halo mass values:

# %%
mass_true = dataset_v['halo_mass']
features = dataset_v.drop(['halo_mass'], axis=1)

# %%
mass_pred = dnn_model.predict(features)

# %%
mass_pred_df = pd.DataFrame(mass_pred, columns = ['halo_mass'])

# %%
mass_pred_df
# Out:
#           halo_mass
# 0      27559.837891
# 1      18690.228516
# 2      26008.806641
# 3      61856.304688
# 4       8070.036133
# ...             ...
# 62740   9308.383789
# 62741  22293.017578
# 62742  31715.501953
# 62743  26604.626953
# 62744  17907.166016
#
# [62745 rows x 1 columns]

# %%
plt.figure(figsize=(10, 6))
hist_plot = mass_true.hist(bins=15)
plt.xlabel('halo_mass')
plt.ylabel('num_p')
plt.show()

# %%
plt.figure(figsize=(10, 6))
hist_plot = mass_pred_df.hist(bins=30)
plt.xlabel('halo_mass')
plt.ylabel('num_p')
plt.show()
